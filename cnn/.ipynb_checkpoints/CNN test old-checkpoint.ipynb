# %%
import rasterio
import numpy as np
import random
import math
import itertools
import os
import sys
import resnet as rs
import importlib
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import classifier_utilities as cu
import new_classifier_utilities as nw
# Out:
# Using TensorFlow backend.

# %%
importlib.reload(cu)
# Out:
# <module 'classifier_utilities' from '/host/Desktop/cnn_dev/florence_mapping/classifier_utilities.py'>

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1";

# %%
landsat_datasets, sentinel_datasets, dem_datasets, label_dataset = cu.load_data()

# %%
batch_size = 25
epochs = 200
num_classes = len(cu.indexed_dictionary)

# input image dimensions
tile_side = 64
img_rows, img_cols = tile_side, tile_side
img_bands = landsat_datasets[0].count + sentinel_datasets[0].count + dem_datasets[0].count - 1

input_shape = (img_cols,img_rows,img_bands)
print(input_shape)
# Out:
# (64, 64, 10)

# %%
pixels = nw.gen_balanced_pixel_locations(landsat_datasets[1:2], 80000, label_dataset=label_dataset)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(len(pixels))
# Out:
# 60573

# %%
clear_pixels = cu.delete_black_tiles(landsat_datasets[1:2], pixels, tile_side = tile_side)

# %%
buckets = cu.pixel_balance(pixels, landsat_datasets[1:2], label_dataset)
for i in range(len(cu.indexed_dictionary)):
    print("{}:{}".format(cu.indexed_dictionary[i], buckets[i]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9666018bbfc9> in <module>
# ----> 1 buckets = cu.pixel_balance(pixels, landsat_datasets[1:2], label_dataset)
#       2 for i in range(len(cu.indexed_dictionary)):
#       3     print("{}:{}".format(cu.indexed_dictionary[i], buckets[i]))
#
# /host/Desktop/cnn_dev/florence_mapping/classifier_utilities.py in pixel_balance(pixels, landsat_datasets, label_dataset, merge)
#     102         # image is huge so we need this to just get a single position
#     103         window = ((row, row+1), (col, col+1))
# --> 104         data = label_dataset.read(1, window=window, masked=False, boundless=True)
#     105         if merge:
#     106             data = merge_classes(data)
#
# rasterio/_io.pyx in rasterio._io.DatasetReaderBase.read()
#
# /usr/local/lib/python3.5/dist-packages/rasterio/vrt.py in _boundless_vrt_doc(src_dataset, nodata, background, hidenodata, width, height, transform, masked)
#     216         dstrect.attrib['ySize'] = str(src_dataset.height)
#     217
# --> 218     return ET.tostring(vrtdataset).decode('ascii')
#
# /usr/lib/python3.5/xml/etree/ElementTree.py in tostring(element, encoding, method, short_empty_elements)
#    1121     stream = io.StringIO() if encoding == 'unicode' else io.BytesIO()
#    1122     ElementTree(element).write(stream, encoding, method=method,
# -> 1123                                short_empty_elements=short_empty_elements)
#    1124     return stream.getvalue()
#    1125
#
# /usr/lib/python3.5/xml/etree/ElementTree.py in write(self, file_or_filename, encoding, xml_declaration, default_namespace, method, short_empty_elements)
#     773                 serialize = _serialize[method]
#     774                 serialize(write, self._root, qnames, namespaces,
# --> 775                           short_empty_elements=short_empty_elements)
#     776
#     777     def write_c14n(self, file):
#
# /usr/lib/python3.5/xml/etree/ElementTree.py in _serialize_xml(write, elem, qnames, namespaces, short_empty_elements, **kwargs)
#     931                     else:
#     932                         v = _escape_attrib(v)
# --> 933                     write(" %s=\"%s\"" % (qnames[k], v))
#     934             if text or len(elem) or not short_empty_elements:
#     935                 write(">")
#
# /usr/lib/python3.5/codecs.py in reset(self)
#     273         raise NotImplementedError
#     274
# --> 275     def reset(self):
#     276         """
#     277         Reset the decoder to the initial state.
#
# KeyboardInterrupt:

# %%
train_px, val_px, test_px = cu.train_val_test_split(pixels, 0.7, 0.8)

# %%
print(len(train_px))
print(len(val_px))
print(len(test_px))
# Out:
# 42401
# 14537
# 6543

# %%
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, SeparableConv2D
from keras.layers import Activation, BatchNormalization
from keras.optimizers import SGD, Adadelta, Adam
from keras import Input
from keras import Model

# %%
def make_model(in_shape):
    input_tensor = Input(shape = in_shape)
    
    conv_1 = SeparableConv2D(64, kernel_size=(3,3), activation='elu') (input_tensor)
    norm_1 = BatchNormalization() (conv_1)
    dropout_1 = Dropout(rate=0.5) (norm_1)
    pool_1 = MaxPooling2D() (dropout_1)
    
    
    conv_2 = SeparableConv2D(64, kernel_size=(3,3), activation='elu') (pool_1)
    norm_2 = BatchNormalization() (conv_2)
    pool_2 = MaxPooling2D() (norm_2)
    
    conv_3 = SeparableConv2D(64, kernel_size=(3,3), activation='elu') (pool_2)
    norm_3 = BatchNormalization() (conv_3)
    dropout_3 = Dropout(rate=0.5) (norm_3)
    pool_3 = MaxPooling2D() (dropout_3)

    
    flatten = Flatten() (pool_3)
    dense = Dense(128, activation='elu') (flatten)
    output = Dense(num_classes,activation='softmax') (dense)
    model = Model(inputs=input_tensor, outputs=output)
    return model

# %%
#model = rs.ResnetBuilder.build_resnet_34(input_shape,num_classes)
model = make_model(input_shape)

# %%
pixels = nw.gen_balanced_pixels(image_datasets, train_count, label_dataset, merge=False)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 10)        0
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 62, 62, 64)        794
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 62, 62, 64)        256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 62, 62, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# separable_conv2d_2 (Separabl (None, 29, 29, 64)        4736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 29, 29, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 12, 12, 64)        4736
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               295040
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                2064
# =================================================================
# Total params: 308,138
# Trainable params: 307,754
# Non-trainable params: 384
# _________________________________________________________________

# %%
opt = Adam(lr= 0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit_generator(generator=nw.tile_generator(landsat_datasets[1:2], sentinel_datasets[1:2], dem_datasets[1:2], label_dataset, tile_side, tile_side, train_px, batch_size), 
                    steps_per_epoch=len(train_px) // batch_size, epochs=epochs, verbose=1,
                    validation_data=nw.tile_generator(landsat_datasets[1:2], sentinel_datasets[1:2], dem_datasets[1:2], label_dataset, tile_side, tile_side, val_px, batch_size),
                    validation_steps=len(val_px)// batch_size)
# Out:
# Epoch 1/200
# 1696/1696 [==============================] - 253s 149ms/step - loss: 2.8836 - acc: 0.1371 - val_loss: 1.1921e-07 - val_acc: 0.0317
# Epoch 2/200
# 1696/1696 [==============================] - 252s 149ms/step - loss: 2.3851 - acc: 0.2048 - val_loss: 1.1921e-07 - val_acc: 0.0318
# Epoch 3/200
#  176/1696 [==>...........................] - ETA: 2:46 - loss: 2.3540 - acc: 0.2116
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-d273eca8da32> in <module>
#       2                     steps_per_epoch=len(train_px) // batch_size, epochs=epochs, verbose=1,
#       3                     validation_data=nw.tile_generator(landsat_datasets[1:2], sentinel_datasets[1:2], dem_datasets[1:2], label_dataset, tile_side, tile_side, val_px, batch_size),
# ----> 4                     validation_steps=len(val_px)// batch_size)
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluate model

# %%
cu.evaluate_cnn(model, landsat_datasets[1:2], sentinel_datasets[1:2], dem_datasets[1:2], label_dataset, tile_side, test_px)
# Out:
# 92/92 [==============================] - 24s 257ms/step
# [11 11  2 ...  8  4  9]
# [10 11 12 ... 10 12 10]
# /host/Desktop/cnn_dev/florence_mapping/classifier_utilities.py:639: RuntimeWarning: invalid value encountered in true_divide
#   cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
# ACCURACY
# 0.14198369565217392

# %%
buckets = cu.pixel_balance(train_px, landsat_datasets[1:2], label_dataset)
for i in range(len(cu.indexed_dictionary)):
    print("{}:{}".format(cu.indexed_dictionary[i], buckets[i]))
# Out:
# Water:596.0
# Snow/Ice:0.0
# Open Space Developed:3511.0
# Low Intensity Developed:0.0
# Medium Intensity Developed:3496.0
# High Intensity Developed:0.0
# Barren Land:1091.0
# Deciduous Forest:3535.0
# Evergreen Forest:3568.0
# Mixed Forest:3471.0
# Scrub/Shrub:3503.0
# Grassland / Herbaceous:3501.0
# Pasture/Hay:3425.0
# Cultivated Land:3489.0
# Woody Wetland:3517.0
# Emergent Herbaceous Wetlands:1479.0
